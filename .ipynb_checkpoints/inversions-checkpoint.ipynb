# %% [markdown]
# # Using Atmospheric Models and Evolutionary Grids for inversions
#
#
# The objective of this notebook is to show how different grids of evolutionary models of exoplanets can be used to infer the mass of exoplanets from their flux. `oplanet` and its `ExoPlInversion` class unify different grids ([Sonora](https://zenodo.org/records/5063476), [Linder](http://cdsarc.u-strasbg.fr/ftp/J/A+A/623/A85/cooling_curves/), [ATMO](https://perso.ens-lyon.fr/isabelle.baraffe/ATMO2020/) and Hades) in one single sturcture. Inversions can thus be performed through linear interpolation.
#
# References:
# - [Phillips et al. 2020](https://www.aanda.org/articles/aa/pdf/2020/05/aa37381-19.pdf)
# - [Linder et al. 2019](https://www.aanda.org/articles/aa/full_html/2019/03/aa33873-18/aa33873-18.html)
# - [Marley et al. 2021](https://doi.org/10.5281/zenodo.5063475)

# %%
from oplanet import EInversion, NSystem
from oakley import *

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# First, let's test our inversion scheme on known systems. The inversion will typically be used from photmetry to mass, but here we will try to invert mass from intrinsic temeprature instead, as the latter are easier to find in the litterature.

# %%
# 1. Get the temperatures
planets_df = pd.DataFrame({
    "planet": [
        "beta Pic b", "51 Eri b","HR 8799 b", "HR 8799 c", "HR 8799 d",
        "HR 8799 e", "HIP 65426 b", "PDS 70 b", "PDS 70 c", "2M1207 b",
        "GJ 504 b", "HIP 99770 b",
    ], # all self-luminous planets
    "t_int_k": [1700,700,1000,1100,1100,1200,1300,1100,1000,1000,550,1300],
})

# %% [markdown]
# For these planets, we want the age of the system as well as the known mass of the planet. Let's take one of them as an example.

# %%
from oplanet.nsystem import oplanet_temp_config

# %%
oplanet_temp_config
# Out:
# {'system': {'references': [],
#   'properties': {'parallax_mas': 1, 'distance_pc': 1, 'ra': 1, 'dec': 1},
#   'fallback': False,
#   'order_authors': True},
#  'star': {'references': [],
#   'properties': {'age_myr': 1,
#    'mass_solar': 1,
#    'radius_solar': 1,
#    'metallicity_dex': 1,
#    'system.distance_pc': 1},
#   'fallback': False,
#   'order_authors': True},
#  'planet': {'references': [],
#   'properties': {'star.age_myr': 1,
#    'system.distance_pc': 1,
#    'orbital_period_yrs': 2,
#    'mass_sini_mjup': 1,
#    'mass_mjup': 3,
#    'sma_au': 2,
#    'eccentricity': 1,
#    'inclination_deg': 1,
#    'arg_periastron_deg': 1,
#    'time_periastron_jd': 1,
#    'rv_amplitude_ms': 1},
#   'fallback': False,
#   'order_authors': True}}

# %%
nsystem = NSystem("HR 8799")
nsystem.star.display()
# Out:
# [i] Star HR 8799 properties:
#  > Age (Myr):                               [nan nan nan]
#  > Mass (solar masses):                     [ 1.61      0.320028 -0.213299]
#  > Radius (solar radii):                    [ 1.49338   0.049341 -0.050935]
#  > Luminosity (solar luminosities):         [ 0.73347  0.01645 -0.01535]
#  > Effective temperature (K):               [7204.58   83.84 -129.54]
#  > Irradiation temparature at 1 arcsec (K): [ 6.61068123e+01 -5.01466424e-01 -4.17324258e-03]
#  > Metallicity (dex):                       [nan nan nan]
#  > Spectral type:                           nan
#  > Reference:                               TICv8
#  > Row:                                     0/15

# %%
with Task("Adding property priorities"):
    nsystem.add_property_priority("star.age_myr", 10)
    #nsystem.add_property_priority("b.", 10)
with Task("Display"):
    nsystem.star.display()
# Out:
# [~] Adding property priorities (8.309s)
# [~] Display
#  > [i] Star HR 8799 properties:
#  >> Age (Myr):                               [ 60. 100. -30.]
#  >> Mass (solar masses):                     [ 1.5  0.3 -0.3]
#  >> Radius (solar radii):                    [nan nan nan]
#  >> Luminosity (solar luminosities):         [ 0.69197  0.03476 -0.03779]
#  >> Effective temperature (K):               [nan nan nan]
#  >> Irradiation temparature at 1 arcsec (K): [nan nan nan]
#  >> Metallicity (dex):                       [-0.47   nan   nan]
#  >> Spectral type:                           nan
#  >> Reference:                               Marois et al. 2008
#  >> Row:                                     1/15
#  > [~] Task completed after: 0.044s

# %%
nsystem.add_property_priority("age_myr", 10)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 nsystem.add_property_priority("age_myr", 10)
#
# File ~/Documents/code/perso/oplanet/oplanet/nsystem.py:341, in NSystem.add_property_priority(self, property_name, weight)
#     339 current_properties = copy.deepcopy(oplanet_temp_config[self._config_key]["properties"])
#     340 current_properties[property_name] = weight
# --> 341 self.set_config(properties=current_properties)
#
# File ~/Documents/code/perso/oplanet/oplanet/nsystem.py:270, in NSystem.set_config(self, references, properties, fallback, order_authors)
#     268         assert isinstance(prop, str), f"Invalid property name: '{prop}'. Must be a string."
#     269         assert isinstance(value, int), f"Invalid property value: '{value}' for property '{prop}'. Must be an integer."
# --> 270         assert safe_get(self, prop), f"Invalid property name: '{prop}'. Must be a valid property of the NSystem or its subclasses. Current class: {self.__class__.__name__}."
#     271     oplanet_temp_config[self._config_key]["properties"] = properties
#     273 if fallback is not None:
#
# AssertionError: Invalid property name: 'age_myr'. Must be a valid property of the NSystem or its subclasses. Current class: NSystem.

# %%
nsystem.st
# Out:
# 0      NaN
# 1     0.06
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7     0.06
# 8      NaN
# 9      NaN
# 10    0.06
# 11     NaN
# 12     NaN
# 13     NaN
# 14    0.03
# 15     NaN
# Name: st_age, dtype: float64

# %% [markdown]
# Too bad, the age of the system isn't available here! But this is only one row of the archive, maybe there is an other row

# %%
# 2. Add ages and masses*
for planet in ProgressBar(planets_df["planet"]):
    system_name = planet[:-1].strip()
    planet_letter = planet[-1]
    nsystem = NSystem(system_name)
    #nsystem.add_reference_priority("age_myr", 100)
    #nsystem.add_reference_priority("mass_mjup", 100)
    star = nsystem.star
    planet = nsystem._get_planet(planet_letter)

    age_myr = star.age_myr[0]
    age_myr_upper = age_myr + star.age_myr[1]
    age_myr_lower = age_myr + star.age_myr[2]
    mass_mjup = planet.mass_mjup[0]
    mass_mjup_upper = mass_mjup + planet.mass_mjup[1]
    mass_mjup_lower = mass_mjup + planet.mass_mjup[2]
    planets_df.loc[planets_df["planet"] == planet, "age_myr"] = age_myr
    planets_df.loc[planets_df["planet"] == planet, "age_myr_upper"] = age_myr_upper
    planets_df.loc[planets_df["planet"] == planet, "age_myr_lower"] = age_myr_lower
    planets_df.loc[planets_df["planet"] == planet, "mass_mjup"] = mass_mjup
    planets_df.loc[planets_df["planet"] == planet, "mass_mjup_upper"] = mass_mjup_upper
    planets_df.loc[planets_df["planet"] == planet, "mass_mjup_lower"] = mass_mjup_lower
planets_df["metallicity_solar_dex"] = 0 

planets_df

# %%
nsystem.display()
# Out:
# [i] Looking at system properties
#  > Star name:             HIP 99770
#  > Number of planets:     1
#  > Dataframe shape:       (2, 355)
#  > Star:                  <NStar(HIP 99770, 2 rows)>
#  > Planets:               [<NPlanet(HIP 99770 b, 2 rows)>]
#  > Distance (pc):         [40.0765  0.2847 -0.2807]
#  > Parallax (mas):        [24.9257    0.174665 -0.174665]
#  > Coordinates (RA, Dec): (303.6338, 36.8066)
#  > Reference:             TICv8
#  > Row:                   0/1

# %%
nsystem = NSystem("Beta Pictoris")

# %%
nsystem.b.display()
# Out:
# [i] Planet bet Pic b properties:
#  > Letter:                       b
#  > Discovery year:               2008
#  > Discovery method:             Imaging
#  > Controversial:                False
#  > Orbital period (yrs):         [23.27994524  0.45995893 -0.45995893]
#  > Mass (Mjup):                  [ 9.   1.6 -1.6]
#  > Mass sin(i) (Mjup):           [nan nan nan]
#  > Semi-major axis (AU):         [ 9.9   0.05 -0.05]
#  > Eccentricity:                 [ 0.1   0.01 -0.01]
#  > Inclination (deg):            [ 8.899e+01  1.000e-02 -1.000e-02]
#  > Argument of periastron (deg): [196.9   3.5  -3.5]
#  > Time of periastron (JD):      [nan nan nan]
#  > RV amplitude (m/s):           [nan nan nan]
#  > Radius (Rjup):                [nan nan nan]
#  > Reference:                    Nowak et al. 2020
#  > Row:                          0/9

# %%
nsystem.display_priorities()
# Out:
# [?] Row priorities for system: (ref-match, val-notna, err-notna, err-range)
#  > 00: Row 0: TICv8 --> (0, 4, 5.0, 0.5)
#  > 01: Row 1: TICv8 --> (0, 4, 5.0, 0.5)
#  > 02: Row 2: TICv8 --> (0, 4, 5.0, 0.5)
#  > 03: Row 3: TICv8 --> (0, 4, 5.0, 0.5)
#  > 04: Row 4: TICv8 --> (0, 4, 5.0, 0.5)
#  > 05: Row 5: TICv8 --> (0, 4, 5.0, 0.5)
#  > 06: Row 6: TICv8 --> (0, 4, 5.0, 0.5)
#  > 07: Row 7: TICv8 --> (0, 4, 5.0, 0.5)
#  > 08: Row 8: TICv8 --> (0, 4, 5.0, 0.5)
#  > 09: Row 9: TICv8 --> (0, 4, 5.0, 0.5)
#  > 10: Row 10: TICv8 --> (0, 4, 5.0, 0.5)
#  > 11: Row 11: TICv8 --> (0, 4, 5.0, 0.5)
#  > 12: Row 12: TICv8 --> (0, 4, 5.0, 0.5)

# %%
nsystem.set_config
