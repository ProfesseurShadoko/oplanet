# %%
from oplanet import *

system = NSystem("LHS 1140")

# %%
system.star
# Out:
# <NStar(LHS 1140, 11 rows)>

# %%
system.distance_pc
# Out:
# array([14.9861,  0.0153, -0.0152])

# %%
system.display()
# Out:
# [i] Looking at system properties
#  > Star name:             LHS 1140
#  > Number of planets:     2
#  > Dataframe shape:       (11, 355)
#  > Star:                  <NStar(LHS 1140, 11 rows)>
#  > Planets:               [<NPlanet(LHS 1140 c, 5 rows)>, <NPlanet(LHS 1140 b, 6 rows)>]
#  > Distance (pc):         [14.9861  0.0153 -0.0152]
#  > Parallax (mas):        [66.6996     0.0673611 -0.0673611]
#  > Coordinates (RA, Dec): (11.2486, -15.2741)
#  > Reference:             TICv8
#  > Row:                   0/10

# %%
system.star.display()
# Out:
# [i] Star LHS 1140 properties:
#  > Age (Myr):                               [  nan   nan 5000.]
#  > Mass (solar masses):                     [ 0.1844  0.0045 -0.0045]
#  > Radius (solar radii):                    [ 0.2159  0.003  -0.003 ]
#  > Luminosity (solar luminosities):         [-2.42022  0.033   -0.03572]
#  > Effective temperature (K):               [3096.   48.  -48.]
#  > Irradiation temparature at 1 arcsec (K): [17.91910267  0.14173005 -0.14665736]
#  > Metallicity (dex):                       [-0.15  0.09 -0.09]
#  > Spectral type:                           nan
#  > Reference:                               Cadieux et al. 2024
#  > Row:                                     2/10

# %%
system.b.display()
# Out:
# [i] Planet LHS 1140 b properties:
#  > Letter:                       b
#  > Discovery year:               2017
#  > Discovery method:             Transit
#  > Orbital period (yrs):         [ 6.77260507e-02  1.12251882e-06 -1.09514031e-06]
#  > Mass (Mjup):                  [ 0.02007372  0.00144732 -0.00138439]
#  > Mass sin(i) (Mjup):           [ 0.01916128  0.00151025 -0.00147879]
#  > Semi-major axis (AU):         [ 0.0957  0.0019 -0.0019]
#  > Eccentricity:                 [  nan 0.043   nan]
#  > Inclination (deg):            [ 8.9877e+01  4.9000e-02 -4.5000e-02]
#  > Argument of periastron (deg): [nan nan nan]
#  > Time of periastron (JD):      [nan nan nan]
#  > RV amplitude (m/s):           [ 4.21  0.24 -0.24]
#  > Radius (Rjup):                [ 0.14586518  0.00410385 -0.00410385]
#  > Reference:                    Lillo-Box et al. 2020
#  > Row:                          1/5

# %%
system.b.display(5)
# Out:
# [i] Planet LHS 1140 b properties:
#  > Letter:                       b
#  > Discovery year:               2017
#  > Discovery method:             Transit
#  > Orbital period (yrs):         [ 6.77261027e-02  2.19028063e-07 -2.19028063e-07]
#  > Mass (Mjup):                  [ 0.02196143  0.00280024 -0.00280024]
#  > Mass sin(i) (Mjup):           [nan nan nan]
#  > Semi-major axis (AU):         [ 0.0936  0.0024 -0.0024]
#  > Eccentricity:                 [ nan 0.06  nan]
#  > Inclination (deg):            [ 8.989e+01  5.000e-02 -3.000e-02]
#  > Argument of periastron (deg): [nan nan nan]
#  > Time of periastron (JD):      [nan nan nan]
#  > RV amplitude (m/s):           [ 4.85  0.55 -0.55]
#  > Radius (Rjup):                [ 0.15407262  0.00285485 -0.00285485]
#  > Reference:                    Ment et al. 2019
#  > Row:                          5/5

# %%
system.b.df["pl_orbeccen"]
# Out:
# 0    0.043
# 1    0.096
# 2      NaN
# 3      NaN
# 4    0.290
# 5    0.060
# Name: pl_orbeccen, dtype: float64

# %%
system.c.display()
# Out:
# [i] Planet LHS 1140 c properties:
#  > Letter:                       c
#  > Discovery year:               2018
#  > Discovery method:             Transit
#  > Orbital period (yrs):         [ 1.03433812e-02  8.21355236e-08 -8.21355236e-08]
#  > Mass (Mjup):                  [ 0.00553758  0.00053488 -0.00050342]
#  > Mass sin(i) (Mjup):           [ 0.00538026  0.00056634 -0.00056634]
#  > Semi-major axis (AU):         [ 0.02734  0.00054 -0.00054]
#  > Eccentricity:                 [ nan 0.05  nan]
#  > Inclination (deg):            [ 8.9913e+01  4.6000e-02 -4.9000e-02]
#  > Argument of periastron (deg): [nan nan nan]
#  > Time of periastron (JD):      [nan nan nan]
#  > RV amplitude (m/s):           [ 2.22  0.2  -0.2 ]
#  > Radius (Rjup):                [ 0.10429137  0.00330092 -0.00339014]
#  > Reference:                    Lillo-Box et al. 2020
#  > Row:                          2/4
